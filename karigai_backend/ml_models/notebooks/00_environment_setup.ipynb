# %% [markdown]
# # KarigAI ML Environment Setup
#
# This notebook verifies the ML development environment and checks all dependencies.

# %%
import sys
sys.path.append('../..')

from ml_models.utils.setup_environment import (
    check_gpu_availability,
    check_system_requirements,
    print_environment_summary
)

# %% [markdown]
# ## Check System Requirements

# %%
system_info = check_system_requirements()
gpu_info = check_gpu_availability()

print_environment_summary(gpu_info, system_info)

# %% [markdown]
# ## Test PyTorch

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU count: {torch.cuda.device_count()}")
    print(f"Current GPU: {torch.cuda.get_device_name(0)}")

# Test tensor operations
x = torch.rand(5, 3)
print(f"\nTest tensor:\n{x}")

if torch.cuda.is_available():
    x_gpu = x.cuda()
    print(f"\nTensor on GPU: {x_gpu.device}")

# %% [markdown]
# ## Test TensorFlow (Optional)

# %%
try:
    import tensorflow as tf
    print(f"TensorFlow version: {tf.__version__}")
    print(f"GPU devices: {tf.config.list_physical_devices('GPU')}")
except ImportError:
    print("TensorFlow not installed")

# %% [markdown]
# ## Test Transformers Library

# %%
from transformers import AutoTokenizer, AutoModel

print("Loading a small test model...")
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")

# Test inference
text = "Hello, this is a test!"
inputs = tokenizer(text, return_tensors="pt")
outputs = model(**inputs)

print(f"Input shape: {inputs['input_ids'].shape}")
print(f"Output shape: {outputs.last_hidden_state.shape}")
print("✅ Transformers library working correctly!")

# %% [markdown]
# ## Test MLflow

# %%
import mlflow

print(f"MLflow version: {mlflow.__version__}")
print(f"Tracking URI: {mlflow.get_tracking_uri()}")

# Test logging
with mlflow.start_run(run_name="test_run"):
    mlflow.log_param("test_param", "test_value")
    mlflow.log_metric("test_metric", 0.95)
    print("✅ MLflow logging working correctly!")

# %% [markdown]
# ## Environment Ready!
#
# If all cells above ran successfully, your environment is ready for model development.
#
# Next steps:
# 1. Collect and prepare datasets
# 2. Start with speech recognition model development
# 3. Use the training pipeline for model training
